# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Plot style

# %%
plt.style.use('seaborn')

# %% [markdown]
# # Data

# %%
data = pd.read_csv('data/SamDysch_glucose_2-5-2022.csv', skiprows=[0])
data.index = pd.to_datetime(data['Device Timestamp'], format="%d-%m-%Y %H:%M")

to_keep = [
    'Record Type',
    'Historic Glucose mmol/L',
    'Scan Glucose mmol/L',
    'Notes'
]
    
data = data[to_keep]
print(data.head())
# Out:
#                      Record Type  Historic Glucose mmol/L  \
# Device Timestamp
# 2019-12-09 19:04:00            0                      6.8
# 2019-12-09 19:20:00            0                      7.6
# 2019-12-09 19:35:00            0                      7.7
# 2019-12-09 19:50:00            0                      7.2
# 2019-12-09 20:05:00            0                      5.8
#
#                      Scan Glucose mmol/L Notes
# Device Timestamp
# 2019-12-09 19:04:00                  NaN   NaN
# 2019-12-09 19:20:00                  NaN   NaN
# 2019-12-09 19:35:00                  NaN   NaN
# 2019-12-09 19:50:00                  NaN   NaN
# 2019-12-09 20:05:00                  NaN   NaN
# /home/sdysch/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3169: DtypeWarning: Columns (13) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
fig, ax = plt.subplots(1, 1, figsize=(50, 10))
ax.plot(data['Scan Glucose mmol/L'])
plt.show()
